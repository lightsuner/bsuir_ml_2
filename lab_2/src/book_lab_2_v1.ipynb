# %% [markdown]
# **Задание 1.**
#
# Реализуйте полносвязную нейронную сеть с помощью библиотеки Tensor Flow. В качестве алгоритма оптимизации можно использовать, например, стохастический градиент (Stochastic Gradient Descent, SGD). Определите количество скрытых слоев от 1 до 5, количество нейронов в каждом из слоев до нескольких сотен, а также их функции активации (кусочно-линейная, сигмоидная, гиперболический тангенс и т.д.).
#
# **Задание 2.**
#
# Как улучшилась точность классификатора по сравнению с логистической регрессией?
#
# **Задание 3.**
#
# Используйте регуляризацию и метод сброса нейронов (dropout) для борьбы с переобучением. Как улучшилось качество классификации?
#
# **Задание 4.**
#
# Воспользуйтесь динамически изменяемой скоростью обучения (learning rate). Наилучшая точность, достигнутая с помощью данной модели составляет 97.1%. Какую точность демонстрирует Ваша реализованная модель?

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import numpy as np
import tensorflow as tf
import scipy.io
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
import matplotlib.pyplot as plt

# %%
tf.__version__
# Out:
# '1.14.0'

# %%
large_dataset_path = '../../lab_1/src/notMNIST_large_clean.mat'
small_dataset_path = '../../lab_1/src/notMNIST_small_uniq.mat'

# %%
chars = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
def prepare_dataset(dataset, records=None):
    data = list()
    labels = list()

    lb = preprocessing.LabelBinarizer()
    lb.fit(chars)
    
    if records:
        one = int(records / len(chars))
        #check
        for ch in chars:
            ch_len = len(dataset[ch])
            assert ch_len >= one, f'"{ch}" has {ch_len} items but required {one}'
        #print(one)
        for ch in chars:
            indexes = np.random.choice(len(dataset[ch]), one)
            picked_elements = dataset[ch][indexes] / 255
            data.extend(picked_elements)
            labels.extend(np.tile(lb.transform([ch])[0], (one, 1)))
    else:
        for ch in chars:
            data.extend(dataset[ch]/255)
            labels.extend(np.tile(lb.transform([ch])[0], (len(dataset[ch]), 1)))
    
    data = np.array(data)
    labels = np.array(labels)
    
    return resample(data, labels)

# %%
small_data = scipy.io.loadmat(small_dataset_path)
test_X, test_y = prepare_dataset(small_data)

# %%
large_data = scipy.io.loadmat(large_dataset_path)
train_X, train_y = prepare_dataset(large_data, 400000)
train_X.shape
# Out:
# (400000, 784)

# %%
g_epochs = 100
g_batch_size = 512

# %%
class Lab2Model():
    def __init__(self, var_scope, layers_info, reg=0.0, dropout=0.0, lr=0.005, adaptive_lr=False):
        self.var_scope = var_scope
        self.layers_info = layers_info
        self.layers_count = len(layers_info)
        self.regularization = reg
        self.dropout = dropout
        self.learning_rate = lr
        self.learning_rate_adaptive = adaptive_lr
        self.session = None
    
    def __del__(self): 
        if self.session:
            self.session.close()
        
    def compile(self):
        self.input = tf.placeholder(tf.float32, shape=[None, self.layers_info[0]])
        self.expected_output = tf.placeholder(tf.float32, shape=[None, self.layers_info[-1]])
        
        self.hidden_layers = {}
        self.hidden_layers_W = {}
        self.hidden_layers_b = {}
        
        self.dropout_rate = tf.placeholder(tf.float32)
        
        prev_layer = self.input
        
        for layer_idx in self.__hidden_layer_iter():            
            units = self.layers_info[layer_idx]
            self.hidden_layers[layer_idx] = self.__fc_layer(layer_idx, prev_layer, units)
            prev_layer = self.hidden_layers[layer_idx]
        
        self.output_layer = self.__fc_layer(self.layers_count - 1, prev_layer, self.layers_info[-1], activ=None)
        
        self.loss = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits_v2(labels=self.expected_output, logits=self.output_layer)
        )
        
        if self.regularization:
            reg_sum = 0
            for layer_idx in self.__hidden_layer_iter():  
                reg_sum += tf.nn.l2_loss(self.hidden_layers_W[layer_idx])
            
            self.loss = tf.reduce_mean(self.loss + reg_sum * self.regularization)
        
        self.lr = tf.placeholder(tf.float32, shape=[])
        
        self.optimizer = tf.train.GradientDescentOptimizer(
            learning_rate=self.learning_rate
        ).minimize(self.loss)
        
        self.prediction = tf.nn.softmax(self.output_layer)
        self.accuracy = tf.reduce_mean(
            tf.cast(
                tf.equal(tf.argmax(self.prediction, 1), tf.argmax(self.expected_output, 1)),
                tf.float32,
            )
        )
                
        self.session = tf.Session()
        self.session.run(tf.global_variables_initializer())
        
        self.history = {
            'acc_train': [],
            'acc_valid': [],
            'loss_train': [],
            'loss_valid': []
        }
    
    def fit(self, x=None, y=None, batch_size=64, epochs=1):
        
        valid_size = 0.3
        
        if len(y) * valid_size > 10_000:
            valid_size = 10_000
        
        x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size=valid_size, random_state=50)
        
        print(f'Train size: {len(y_train)},\t Valid size: {len(y_valid)}')
        
        iterations = int(len(y_train) / batch_size)
        
        display_info = int(iterations / 2)
        
        print(f'---------------------------------------------------------------')
        print(f'Epochs: {epochs}\t| Iterations: {iterations}\t| Batch: {batch_size}')
        print(f'---------------------------------------------------------------')
        
        for epoch in range(epochs):
            print('Epoch: {}'.format(epoch + 1))
            
            x_train_epoch, y_train_epoch = resample(x_train, y_train)
            
            lr = self.__next_lr(epoch, epochs)
            #print(lr)
            
            for iteration in range(iterations):
                x_batch, y_batch = self.__next_batch(x_train_epoch, y_train_epoch, batch_size, iteration)

                feed_data = { 
                    self.input: x_batch, 
                    self.expected_output: y_batch, 
                    self.lr: lr, 
                    self.dropout_rate: self.dropout
                }
                
                self.session.run(self.optimizer, feed_dict=feed_data)
                
                #if iteration % display_info == 0:
                #    info_feed_data = { self.input: x_batch, self.expected_output: y_batch, self.dropout_rate: 0}
                #    loss_batch, acc_batch = self.session.run([self.loss, self.accuracy], feed_dict=info_feed_data)
                #    print(f'Itr {iteration}:\t loss={loss_batch:.2f},\t acc={acc_batch:.01%}')
        
        
            feed_data_train = { self.input: x_train, self.expected_output: y_train, self.dropout_rate: 0}
            loss_train, acc_train = self.session.run([self.loss, self.accuracy], feed_dict=feed_data_train)

            self.history['acc_train'].append(acc_train)
            self.history['loss_train'].append(loss_train)

            feed_data_valid = { self.input: x_valid, self.expected_output: y_valid, self.dropout_rate: 0}
            loss_valid, acc_valid = self.session.run([self.loss, self.accuracy], feed_dict=feed_data_valid)

            self.history['acc_valid'].append(acc_valid)
            self.history['loss_valid'].append(loss_valid)

            print('---------------------------------------------------------')
            print('---------------------------------------------------------')
            print(f'train loss: {loss_train:.2f}, train acc: {acc_train:.01%}')
            print(f'valid loss: {loss_valid:.2f}, valid acc: {acc_valid:.01%}')
            print('---------------------------------------------------------')
            print('---------------------------------------------------------')
    
    def predict(self, x=None):
        feed_data = { self.input: x, self.dropout_rate: 0}
        return self.session.run(self.prediction, feed_dict=feed_data)
    
    def evaluate(self, x=None, y=None):
        feed_data = { self.input: x, self.expected_output: y, self.dropout_rate: 0}
        return self.session.run([self.loss, self.accuracy], feed_dict=feed_data)
    
    def __hidden_layer_iter(self):
        return range(1, self.layers_count - 1)
    
    def __next_lr(self, current_iteration, iterations_count):
        if not self.learning_rate_adaptive:
            return self.learning_rate        
        
        adaptive_rate = 30

        return self.learning_rate * adaptive_rate ** (1-(current_iteration / iterations_count))
    
    def __next_batch(self, x, y, batch_size, iteration):
        start = iteration * batch_size
        end = (iteration + 1) * batch_size
        
        return x[start:end], y[start:end]

    def __fc_layer(self, layer_idx, prev_layer, units, activ=tf.nn.relu):
        input_shape = prev_layer.get_shape()[1]

        with tf.variable_scope(self.var_scope, reuse=tf.AUTO_REUSE):
            weights = tf.get_variable(
                'W_' + str(layer_idx), 
                dtype=tf.float32, 
                shape=[input_shape, units], 
                initializer=tf.truncated_normal_initializer(stddev=0.01)
            )

            bias = tf.get_variable(
                'b_' + str(layer_idx), 
                dtype=tf.float32, 
                initializer=tf.constant(0., shape=[units], dtype=tf.float32)
            )
        
        self.hidden_layers_W[layer_idx] = weights
        self.hidden_layers_b[layer_idx] = bias
        
        layer = tf.matmul(prev_layer, weights) + bias
        
        if activ:
            layer = tf.nn.dropout(layer, rate=self.dropout_rate)
            layer = activ(layer)            
        
        return layer
    

#model = Lab2Model('scp_7', [784, 200, 10], lr=0.005, adaptive_lr=True, reg=0.1, dropout=0.5)
#model.compile()
#model.fit(X_tr, y_tr, batch_size=128, epochs=2)
#model.predict(X_tr[0].reshape(1, -1)), y_tr[0]

# %% [markdown]
# **Задание 1.**
#
# Реализуйте полносвязную нейронную сеть с помощью библиотеки Tensor Flow. В качестве алгоритма оптимизации можно использовать, например, стохастический градиент (Stochastic Gradient Descent, SGD). Определите количество скрытых слоев от 1 до 5, количество нейронов в каждом из слоев до нескольких сотен, а также их функции активации (кусочно-линейная, сигмоидная, гиперболический тангенс и т.д.).

# %%
network_config = [784, 150, 150, 10]

# %%
base_model = Lab2Model('base_8', network_config)
base_model.compile()
base_model.fit(train_X, train_y, batch_size=g_batch_size, epochs=g_epochs)
# Out:
# Train size: 390000,	 Valid size: 10000
# ---------------------------------------------------------------
# Epochs: 100	| Iterations: 761	| Batch: 512
# ---------------------------------------------------------------
# Epoch: 1
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.30, train acc: 11.6%
# valid loss: 2.30, valid acc: 11.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 2
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.30, train acc: 10.1%
# valid loss: 2.30, valid acc: 10.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 3
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.30, train acc: 22.4%
# valid loss: 2.30, valid acc: 22.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 4
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.28, train acc: 25.9%
# valid loss: 2.28, valid acc: 25.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 5
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.13, train acc: 30.2%
# valid loss: 2.13, valid acc: 30.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 6
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.58, train acc: 49.3%
# valid loss: 1.58, valid acc: 49.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 7
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.25, train acc: 65.9%
# valid loss: 1.24, valid acc: 66.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 8
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.07, train acc: 71.0%
# valid loss: 1.06, valid acc: 70.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 9
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.99, train acc: 73.4%
# valid loss: 0.99, valid acc: 72.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 10
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.93, train acc: 75.3%
# valid loss: 0.93, valid acc: 75.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 11
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.88, train acc: 77.0%
# valid loss: 0.87, valid acc: 77.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 12
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.84, train acc: 77.9%
# valid loss: 0.83, valid acc: 77.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 13
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.81, train acc: 78.3%
# valid loss: 0.80, valid acc: 78.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 14
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.78, train acc: 78.8%
# valid loss: 0.77, valid acc: 78.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 15
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.75, train acc: 79.3%
# valid loss: 0.75, valid acc: 78.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 16
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.73, train acc: 79.6%
# valid loss: 0.73, valid acc: 79.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 17
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.71, train acc: 80.0%
# valid loss: 0.71, valid acc: 79.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 18
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.70, train acc: 80.3%
# valid loss: 0.69, valid acc: 80.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 19
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.69, train acc: 80.6%
# valid loss: 0.68, valid acc: 80.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 20
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.67, train acc: 80.8%
# valid loss: 0.67, valid acc: 80.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 21
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.66, train acc: 81.0%
# valid loss: 0.66, valid acc: 81.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 22
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.65, train acc: 81.3%
# valid loss: 0.65, valid acc: 81.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 23
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.65, train acc: 81.4%
# valid loss: 0.64, valid acc: 81.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 24
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.64, train acc: 81.6%
# valid loss: 0.63, valid acc: 81.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 25
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 81.8%
# valid loss: 0.63, valid acc: 81.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 26
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 82.0%
# valid loss: 0.62, valid acc: 82.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 27
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 82.2%
# valid loss: 0.61, valid acc: 82.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 28
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 82.3%
# valid loss: 0.61, valid acc: 82.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 29
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 82.4%
# valid loss: 0.60, valid acc: 82.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 30
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 82.6%
# valid loss: 0.60, valid acc: 82.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 31
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 82.8%
# valid loss: 0.59, valid acc: 82.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 32
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 82.9%
# valid loss: 0.59, valid acc: 82.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 33
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.58, train acc: 83.1%
# valid loss: 0.58, valid acc: 83.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 34
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.58, train acc: 83.2%
# valid loss: 0.58, valid acc: 83.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 35
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.57, train acc: 83.3%
# valid loss: 0.57, valid acc: 83.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 36
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.57, train acc: 83.5%
# valid loss: 0.57, valid acc: 83.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 37
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.56, train acc: 83.6%
# valid loss: 0.56, valid acc: 83.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 38
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.56, train acc: 83.7%
# valid loss: 0.56, valid acc: 83.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 39
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.55, train acc: 83.9%
# valid loss: 0.56, valid acc: 84.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 40
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.55, train acc: 84.0%
# valid loss: 0.55, valid acc: 84.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 41
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.55, train acc: 84.1%
# valid loss: 0.55, valid acc: 84.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 42
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.54, train acc: 84.2%
# valid loss: 0.55, valid acc: 84.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 43
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.54, train acc: 84.3%
# valid loss: 0.54, valid acc: 84.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 44
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.53, train acc: 84.4%
# valid loss: 0.54, valid acc: 84.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 45
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.53, train acc: 84.5%
# valid loss: 0.54, valid acc: 84.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 46
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.53, train acc: 84.6%
# valid loss: 0.53, valid acc: 84.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 47
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.52, train acc: 84.7%
# valid loss: 0.53, valid acc: 84.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 48
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.52, train acc: 84.8%
# valid loss: 0.53, valid acc: 84.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 49
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.52, train acc: 84.9%
# valid loss: 0.52, valid acc: 84.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 50
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.51, train acc: 85.1%
# valid loss: 0.52, valid acc: 84.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 51
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.51, train acc: 85.1%
# valid loss: 0.52, valid acc: 85.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 52
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.51, train acc: 85.2%
# valid loss: 0.51, valid acc: 85.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 53
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.50, train acc: 85.3%
# valid loss: 0.51, valid acc: 85.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 54
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.50, train acc: 85.4%
# valid loss: 0.51, valid acc: 85.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 55
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.50, train acc: 85.5%
# valid loss: 0.51, valid acc: 85.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 56
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.49, train acc: 85.5%
# valid loss: 0.50, valid acc: 85.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 57
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.49, train acc: 85.6%
# valid loss: 0.50, valid acc: 85.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 58
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.49, train acc: 85.7%
# valid loss: 0.50, valid acc: 85.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 59
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.49, train acc: 85.7%
# valid loss: 0.50, valid acc: 85.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 60
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.48, train acc: 85.8%
# valid loss: 0.49, valid acc: 85.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 61
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.48, train acc: 85.9%
# valid loss: 0.49, valid acc: 85.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 62
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.48, train acc: 86.0%
# valid loss: 0.49, valid acc: 85.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 63
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.47, train acc: 86.0%
# valid loss: 0.49, valid acc: 85.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 64
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.47, train acc: 86.1%
# valid loss: 0.49, valid acc: 85.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 65
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.47, train acc: 86.2%
# valid loss: 0.48, valid acc: 85.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 66
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.47, train acc: 86.3%
# valid loss: 0.48, valid acc: 85.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 67
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.47, train acc: 86.4%
# valid loss: 0.48, valid acc: 86.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 68
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.46, train acc: 86.4%
# valid loss: 0.48, valid acc: 86.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 69
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.46, train acc: 86.5%
# valid loss: 0.47, valid acc: 86.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 70
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.46, train acc: 86.5%
# valid loss: 0.47, valid acc: 86.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 71
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.46, train acc: 86.6%
# valid loss: 0.47, valid acc: 86.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 72
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.45, train acc: 86.7%
# valid loss: 0.47, valid acc: 86.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 73
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.45, train acc: 86.7%
# valid loss: 0.47, valid acc: 86.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 74
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.45, train acc: 86.8%
# valid loss: 0.47, valid acc: 86.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 75
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.45, train acc: 86.8%
# valid loss: 0.46, valid acc: 86.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 76
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.44, train acc: 86.9%
# valid loss: 0.46, valid acc: 86.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 77
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.44, train acc: 87.0%
# valid loss: 0.46, valid acc: 86.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 78
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.44, train acc: 87.0%
# valid loss: 0.46, valid acc: 86.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 79
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.44, train acc: 87.1%
# valid loss: 0.46, valid acc: 86.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 80
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.44, train acc: 87.1%
# valid loss: 0.46, valid acc: 86.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 81
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.43, train acc: 87.2%
# valid loss: 0.45, valid acc: 87.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 82
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.43, train acc: 87.3%
# valid loss: 0.45, valid acc: 87.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 83
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.43, train acc: 87.3%
# valid loss: 0.45, valid acc: 87.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 84
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.43, train acc: 87.4%
# valid loss: 0.45, valid acc: 87.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 85
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.43, train acc: 87.4%
# valid loss: 0.45, valid acc: 87.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 86
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.42, train acc: 87.5%
# valid loss: 0.44, valid acc: 87.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 87
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.42, train acc: 87.5%
# valid loss: 0.44, valid acc: 87.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 88
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.42, train acc: 87.6%
# valid loss: 0.44, valid acc: 87.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 89
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.42, train acc: 87.6%
# valid loss: 0.44, valid acc: 87.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 90
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.42, train acc: 87.7%
# valid loss: 0.44, valid acc: 87.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 91
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.42, train acc: 87.7%
# valid loss: 0.44, valid acc: 87.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 92
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.41, train acc: 87.8%
# valid loss: 0.44, valid acc: 87.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 93
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.41, train acc: 87.8%
# valid loss: 0.43, valid acc: 87.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 94
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.41, train acc: 87.9%
# valid loss: 0.43, valid acc: 87.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 95
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.41, train acc: 87.9%
# valid loss: 0.43, valid acc: 87.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 96
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.41, train acc: 88.0%
# valid loss: 0.43, valid acc: 87.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 97
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.41, train acc: 88.0%
# valid loss: 0.43, valid acc: 87.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 98
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.40, train acc: 88.1%
# valid loss: 0.43, valid acc: 87.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 99
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.40, train acc: 88.2%
# valid loss: 0.42, valid acc: 87.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 100
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.40, train acc: 88.2%
# valid loss: 0.42, valid acc: 87.8%
# ---------------------------------------------------------
# ---------------------------------------------------------

# %%
base_loss, base_acc = base_model.evaluate(test_X, test_y)
base_loss, base_acc
# Out:
# (0.21200162, 0.93979603)

# %% [markdown]
# **Задание 3.**
#
# Используйте регуляризацию и метод сброса нейронов (dropout) для борьбы с переобучением. Как улучшилось качество классификации?

# %%
reg_drop_model = Lab2Model('reg_drop_9', network_config, reg=0.01, dropout=0.1)
reg_drop_model.compile()
reg_drop_model.fit(train_X, train_y, batch_size=g_batch_size, epochs=g_epochs)
# Out:
# Train size: 390000,	 Valid size: 10000
# ---------------------------------------------------------------
# Epochs: 100	| Iterations: 761	| Batch: 512
# ---------------------------------------------------------------
# Epoch: 1
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.35, train acc: 14.6%
# valid loss: 2.35, valid acc: 14.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 2
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.35, train acc: 10.5%
# valid loss: 2.35, valid acc: 10.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 3
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.34, train acc: 21.4%
# valid loss: 2.34, valid acc: 21.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 4
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.33, train acc: 19.8%
# valid loss: 2.33, valid acc: 19.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 5
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.23, train acc: 21.8%
# valid loss: 2.23, valid acc: 21.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 6
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.92, train acc: 38.0%
# valid loss: 1.92, valid acc: 37.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 7
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.45, train acc: 62.4%
# valid loss: 1.45, valid acc: 62.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 8
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.19, train acc: 69.0%
# valid loss: 1.19, valid acc: 68.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 9
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.12, train acc: 71.3%
# valid loss: 1.11, valid acc: 70.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 10
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.07, train acc: 73.7%
# valid loss: 1.06, valid acc: 73.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 11
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.01, train acc: 75.3%
# valid loss: 1.01, valid acc: 74.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 12
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.96, train acc: 76.6%
# valid loss: 0.96, valid acc: 76.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 13
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.92, train acc: 77.6%
# valid loss: 0.92, valid acc: 77.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 14
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.88, train acc: 78.4%
# valid loss: 0.88, valid acc: 78.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 15
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.86, train acc: 79.0%
# valid loss: 0.86, valid acc: 78.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 16
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.84, train acc: 79.4%
# valid loss: 0.84, valid acc: 79.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 17
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.82, train acc: 79.8%
# valid loss: 0.82, valid acc: 79.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 18
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.81, train acc: 80.1%
# valid loss: 0.81, valid acc: 80.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 19
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.80, train acc: 80.3%
# valid loss: 0.80, valid acc: 80.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 20
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.79, train acc: 80.6%
# valid loss: 0.79, valid acc: 80.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 21
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.78, train acc: 80.8%
# valid loss: 0.78, valid acc: 80.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 22
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.77, train acc: 81.0%
# valid loss: 0.77, valid acc: 81.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 23
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.76, train acc: 81.2%
# valid loss: 0.76, valid acc: 81.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 24
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.76, train acc: 81.4%
# valid loss: 0.75, valid acc: 81.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 25
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.75, train acc: 81.5%
# valid loss: 0.75, valid acc: 81.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 26
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.74, train acc: 81.7%
# valid loss: 0.74, valid acc: 81.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 27
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.74, train acc: 81.8%
# valid loss: 0.74, valid acc: 82.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 28
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.73, train acc: 82.0%
# valid loss: 0.73, valid acc: 82.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 29
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.73, train acc: 82.2%
# valid loss: 0.73, valid acc: 82.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 30
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.72, train acc: 82.2%
# valid loss: 0.72, valid acc: 82.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 31
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.72, train acc: 82.4%
# valid loss: 0.72, valid acc: 82.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 32
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.71, train acc: 82.5%
# valid loss: 0.71, valid acc: 82.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 33
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.71, train acc: 82.6%
# valid loss: 0.71, valid acc: 82.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 34
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.70, train acc: 82.7%
# valid loss: 0.70, valid acc: 82.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 35
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.70, train acc: 82.8%
# valid loss: 0.70, valid acc: 83.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 36
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.70, train acc: 82.9%
# valid loss: 0.70, valid acc: 83.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 37
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.69, train acc: 83.1%
# valid loss: 0.69, valid acc: 83.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 38
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.69, train acc: 83.2%
# valid loss: 0.69, valid acc: 83.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 39
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.68, train acc: 83.3%
# valid loss: 0.68, valid acc: 83.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 40
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.68, train acc: 83.4%
# valid loss: 0.68, valid acc: 83.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 41
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.68, train acc: 83.5%
# valid loss: 0.68, valid acc: 83.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 42
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.67, train acc: 83.6%
# valid loss: 0.68, valid acc: 83.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 43
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.67, train acc: 83.6%
# valid loss: 0.67, valid acc: 83.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 44
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.67, train acc: 83.7%
# valid loss: 0.67, valid acc: 83.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 45
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.67, train acc: 83.8%
# valid loss: 0.67, valid acc: 83.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 46
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.66, train acc: 83.9%
# valid loss: 0.67, valid acc: 83.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 47
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.66, train acc: 84.0%
# valid loss: 0.66, valid acc: 84.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 48
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.66, train acc: 84.0%
# valid loss: 0.66, valid acc: 84.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 49
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.66, train acc: 84.1%
# valid loss: 0.66, valid acc: 84.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 50
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.65, train acc: 84.2%
# valid loss: 0.66, valid acc: 84.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 51
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.65, train acc: 84.3%
# valid loss: 0.65, valid acc: 84.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 52
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.65, train acc: 84.3%
# valid loss: 0.65, valid acc: 84.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 53
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.65, train acc: 84.4%
# valid loss: 0.65, valid acc: 84.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 54
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.64, train acc: 84.5%
# valid loss: 0.65, valid acc: 84.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 55
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.64, train acc: 84.5%
# valid loss: 0.65, valid acc: 84.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 56
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.64, train acc: 84.6%
# valid loss: 0.64, valid acc: 84.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 57
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.64, train acc: 84.6%
# valid loss: 0.64, valid acc: 84.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 58
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.64, train acc: 84.7%
# valid loss: 0.64, valid acc: 84.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 59
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 84.7%
# valid loss: 0.64, valid acc: 84.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 60
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 84.8%
# valid loss: 0.64, valid acc: 84.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 61
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 84.8%
# valid loss: 0.63, valid acc: 84.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 62
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 84.9%
# valid loss: 0.63, valid acc: 84.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 63
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 84.9%
# valid loss: 0.63, valid acc: 84.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 64
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 85.0%
# valid loss: 0.63, valid acc: 84.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 65
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 85.1%
# valid loss: 0.63, valid acc: 84.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 66
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 85.1%
# valid loss: 0.63, valid acc: 84.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 67
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 85.1%
# valid loss: 0.63, valid acc: 84.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 68
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 85.2%
# valid loss: 0.62, valid acc: 85.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 69
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 85.2%
# valid loss: 0.62, valid acc: 85.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 70
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 85.2%
# valid loss: 0.62, valid acc: 84.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 71
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.3%
# valid loss: 0.62, valid acc: 85.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 72
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.4%
# valid loss: 0.62, valid acc: 85.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 73
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.4%
# valid loss: 0.62, valid acc: 85.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 74
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.4%
# valid loss: 0.62, valid acc: 85.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 75
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.5%
# valid loss: 0.62, valid acc: 85.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 76
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.5%
# valid loss: 0.61, valid acc: 85.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 77
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.5%
# valid loss: 0.61, valid acc: 85.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 78
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.5%
# valid loss: 0.61, valid acc: 85.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 79
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.7%
# valid loss: 0.61, valid acc: 85.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 80
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.6%
# valid loss: 0.61, valid acc: 85.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 81
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.7%
# valid loss: 0.61, valid acc: 85.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 82
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.7%
# valid loss: 0.61, valid acc: 85.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 83
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.8%
# valid loss: 0.61, valid acc: 85.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 84
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.8%
# valid loss: 0.61, valid acc: 85.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 85
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.8%
# valid loss: 0.60, valid acc: 85.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 86
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.8%
# valid loss: 0.60, valid acc: 85.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 87
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 85.9%
# valid loss: 0.60, valid acc: 85.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 88
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 85.9%
# valid loss: 0.60, valid acc: 85.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 89
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 85.9%
# valid loss: 0.60, valid acc: 85.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 90
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 85.9%
# valid loss: 0.60, valid acc: 85.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 91
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.0%
# valid loss: 0.60, valid acc: 85.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 92
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.1%
# valid loss: 0.60, valid acc: 86.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 93
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.1%
# valid loss: 0.60, valid acc: 86.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 94
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.1%
# valid loss: 0.60, valid acc: 85.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 95
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.1%
# valid loss: 0.59, valid acc: 86.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 96
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.2%
# valid loss: 0.59, valid acc: 86.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 97
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.58, train acc: 86.2%
# valid loss: 0.59, valid acc: 86.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 98
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.58, train acc: 86.2%
# valid loss: 0.59, valid acc: 86.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 99
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.58, train acc: 86.2%
# valid loss: 0.59, valid acc: 86.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 100
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.58, train acc: 86.2%
# valid loss: 0.59, valid acc: 86.2%
# ---------------------------------------------------------
# ---------------------------------------------------------

# %%
reg_drop_loss, reg_drop_acc = reg_drop_model.evaluate(test_X, test_y)
reg_drop_loss, reg_drop_acc
# Out:
# (0.3661864, 0.9312973)

# %% [markdown]
# **Задание 4.**
#
# Воспользуйтесь динамически изменяемой скоростью обучения (learning rate). Наилучшая точность, достигнутая с помощью данной модели составляет 97.1%. Какую точность демонстрирует Ваша реализованная модель?

# %%
reg_drop_adaptive_model = Lab2Model('reg_drop_9', network_config, reg=0.01, dropout=0.1, adaptive_lr=True)
reg_drop_adaptive_model.compile()
reg_drop_adaptive_model.fit(train_X, train_y, batch_size=g_batch_size, epochs=g_epochs)
# Out:
# Train size: 390000,	 Valid size: 10000
# ---------------------------------------------------------------
# Epochs: 100	| Iterations: 761	| Batch: 512
# ---------------------------------------------------------------
# Epoch: 1
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.35, train acc: 17.8%
# valid loss: 2.35, valid acc: 17.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 2
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.35, train acc: 12.8%
# valid loss: 2.35, valid acc: 13.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 3
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.34, train acc: 20.1%
# valid loss: 2.34, valid acc: 20.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 4
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.32, train acc: 25.4%
# valid loss: 2.32, valid acc: 25.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 5
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.18, train acc: 26.3%
# valid loss: 2.19, valid acc: 25.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 6
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.80, train acc: 47.6%
# valid loss: 1.80, valid acc: 47.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 7
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.30, train acc: 66.4%
# valid loss: 1.30, valid acc: 66.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 8
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.16, train acc: 70.4%
# valid loss: 1.15, valid acc: 70.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 9
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.10, train acc: 72.9%
# valid loss: 1.09, valid acc: 72.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 10
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.05, train acc: 74.4%
# valid loss: 1.05, valid acc: 74.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 11
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.01, train acc: 75.5%
# valid loss: 1.00, valid acc: 75.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 12
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.97, train acc: 76.5%
# valid loss: 0.96, valid acc: 76.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 13
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.93, train acc: 77.3%
# valid loss: 0.93, valid acc: 77.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 14
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.90, train acc: 78.1%
# valid loss: 0.89, valid acc: 78.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 15
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.87, train acc: 78.6%
# valid loss: 0.87, valid acc: 78.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 16
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.85, train acc: 79.0%
# valid loss: 0.85, valid acc: 78.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 17
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.83, train acc: 79.4%
# valid loss: 0.83, valid acc: 79.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 18
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.82, train acc: 79.8%
# valid loss: 0.82, valid acc: 79.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 19
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.81, train acc: 80.0%
# valid loss: 0.81, valid acc: 79.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 20
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.80, train acc: 80.3%
# valid loss: 0.80, valid acc: 80.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 21
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.79, train acc: 80.6%
# valid loss: 0.79, valid acc: 80.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 22
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.78, train acc: 80.8%
# valid loss: 0.78, valid acc: 80.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 23
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.77, train acc: 80.9%
# valid loss: 0.77, valid acc: 81.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 24
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.76, train acc: 81.1%
# valid loss: 0.76, valid acc: 81.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 25
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.76, train acc: 81.3%
# valid loss: 0.76, valid acc: 81.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 26
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.75, train acc: 81.5%
# valid loss: 0.75, valid acc: 81.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 27
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.74, train acc: 81.6%
# valid loss: 0.74, valid acc: 81.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 28
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.74, train acc: 81.8%
# valid loss: 0.74, valid acc: 82.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 29
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.73, train acc: 81.9%
# valid loss: 0.73, valid acc: 82.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 30
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.73, train acc: 82.1%
# valid loss: 0.73, valid acc: 82.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 31
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.72, train acc: 82.3%
# valid loss: 0.72, valid acc: 82.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 32
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.72, train acc: 82.4%
# valid loss: 0.72, valid acc: 82.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 33
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.71, train acc: 82.5%
# valid loss: 0.71, valid acc: 82.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 34
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.71, train acc: 82.6%
# valid loss: 0.71, valid acc: 82.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 35
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.70, train acc: 82.8%
# valid loss: 0.70, valid acc: 82.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 36
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.70, train acc: 82.9%
# valid loss: 0.70, valid acc: 83.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 37
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.70, train acc: 83.0%
# valid loss: 0.70, valid acc: 83.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 38
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.69, train acc: 83.1%
# valid loss: 0.69, valid acc: 83.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 39
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.69, train acc: 83.2%
# valid loss: 0.69, valid acc: 83.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 40
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.69, train acc: 83.3%
# valid loss: 0.69, valid acc: 83.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 41
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.68, train acc: 83.4%
# valid loss: 0.68, valid acc: 83.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 42
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.68, train acc: 83.5%
# valid loss: 0.68, valid acc: 83.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 43
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.68, train acc: 83.6%
# valid loss: 0.68, valid acc: 83.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 44
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.67, train acc: 83.7%
# valid loss: 0.67, valid acc: 83.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 45
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.67, train acc: 83.7%
# valid loss: 0.67, valid acc: 83.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 46
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.67, train acc: 83.8%
# valid loss: 0.67, valid acc: 84.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 47
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.66, train acc: 83.9%
# valid loss: 0.66, valid acc: 84.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 48
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.66, train acc: 83.9%
# valid loss: 0.66, valid acc: 84.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 49
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.66, train acc: 84.0%
# valid loss: 0.66, valid acc: 84.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 50
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.66, train acc: 84.1%
# valid loss: 0.66, valid acc: 84.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 51
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.65, train acc: 84.1%
# valid loss: 0.65, valid acc: 84.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 52
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.65, train acc: 84.3%
# valid loss: 0.65, valid acc: 84.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 53
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.65, train acc: 84.3%
# valid loss: 0.65, valid acc: 84.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 54
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.65, train acc: 84.4%
# valid loss: 0.65, valid acc: 84.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 55
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.64, train acc: 84.4%
# valid loss: 0.65, valid acc: 84.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 56
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.64, train acc: 84.5%
# valid loss: 0.64, valid acc: 84.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 57
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.64, train acc: 84.6%
# valid loss: 0.64, valid acc: 84.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 58
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.64, train acc: 84.6%
# valid loss: 0.64, valid acc: 84.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 59
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.64, train acc: 84.7%
# valid loss: 0.64, valid acc: 84.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 60
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 84.7%
# valid loss: 0.64, valid acc: 84.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 61
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 84.8%
# valid loss: 0.64, valid acc: 84.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 62
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 84.9%
# valid loss: 0.63, valid acc: 84.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 63
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 84.9%
# valid loss: 0.63, valid acc: 84.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 64
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 85.0%
# valid loss: 0.63, valid acc: 84.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 65
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 85.0%
# valid loss: 0.63, valid acc: 84.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 66
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 85.1%
# valid loss: 0.63, valid acc: 84.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 67
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 85.1%
# valid loss: 0.63, valid acc: 85.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 68
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 85.2%
# valid loss: 0.62, valid acc: 85.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 69
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 85.2%
# valid loss: 0.62, valid acc: 85.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 70
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 85.3%
# valid loss: 0.62, valid acc: 85.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 71
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.4%
# valid loss: 0.62, valid acc: 85.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 72
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.4%
# valid loss: 0.62, valid acc: 85.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 73
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.4%
# valid loss: 0.62, valid acc: 85.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 74
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.5%
# valid loss: 0.62, valid acc: 85.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 75
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.5%
# valid loss: 0.61, valid acc: 85.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 76
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.6%
# valid loss: 0.61, valid acc: 85.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 77
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 85.6%
# valid loss: 0.61, valid acc: 85.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 78
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.7%
# valid loss: 0.61, valid acc: 85.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 79
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.7%
# valid loss: 0.61, valid acc: 85.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 80
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.7%
# valid loss: 0.61, valid acc: 85.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 81
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.8%
# valid loss: 0.61, valid acc: 85.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 82
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.8%
# valid loss: 0.61, valid acc: 85.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 83
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.8%
# valid loss: 0.61, valid acc: 85.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 84
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.9%
# valid loss: 0.60, valid acc: 85.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 85
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 85.9%
# valid loss: 0.60, valid acc: 85.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 86
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 85.9%
# valid loss: 0.60, valid acc: 85.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 87
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 85.9%
# valid loss: 0.60, valid acc: 85.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 88
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.0%
# valid loss: 0.60, valid acc: 85.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 89
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.0%
# valid loss: 0.60, valid acc: 85.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 90
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.0%
# valid loss: 0.60, valid acc: 85.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 91
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.1%
# valid loss: 0.60, valid acc: 85.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 92
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.1%
# valid loss: 0.60, valid acc: 85.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 93
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.2%
# valid loss: 0.60, valid acc: 86.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 94
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.2%
# valid loss: 0.59, valid acc: 86.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 95
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 86.2%
# valid loss: 0.59, valid acc: 86.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 96
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.58, train acc: 86.2%
# valid loss: 0.59, valid acc: 86.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 97
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.58, train acc: 86.2%
# valid loss: 0.59, valid acc: 86.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 98
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.58, train acc: 86.2%
# valid loss: 0.59, valid acc: 86.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 99
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.58, train acc: 86.3%
# valid loss: 0.59, valid acc: 86.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 100
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.58, train acc: 86.3%
# valid loss: 0.59, valid acc: 86.3%
# ---------------------------------------------------------
# ---------------------------------------------------------

# %%
reg_drop_adaptive_loss, reg_drop_adaptive_acc = reg_drop_adaptive_model.evaluate(test_X, test_y)
reg_drop_adaptive_loss, reg_drop_adaptive_acc
# Out:
# (0.3660412, 0.93031037)

# %%
reg_model = Lab2Model('reg_9', network_config,adaptive_lr=True)
reg_model.compile()
reg_model.fit(train_X, train_y, batch_size=g_batch_size, epochs=g_epochs)
# Out:
# Train size: 390000,	 Valid size: 10000
# ---------------------------------------------------------------
# Epochs: 100	| Iterations: 761	| Batch: 512
# ---------------------------------------------------------------
# Epoch: 1
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.30, train acc: 10.5%
# valid loss: 2.30, valid acc: 10.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 2
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.30, train acc: 10.1%
# valid loss: 2.30, valid acc: 10.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 3
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.30, train acc: 15.8%
# valid loss: 2.30, valid acc: 15.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 4
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.29, train acc: 23.3%
# valid loss: 2.29, valid acc: 23.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 5
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 2.22, train acc: 24.1%
# valid loss: 2.22, valid acc: 24.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 6
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.67, train acc: 49.4%
# valid loss: 1.68, valid acc: 49.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 7
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.28, train acc: 66.7%
# valid loss: 1.28, valid acc: 66.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 8
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 1.06, train acc: 71.8%
# valid loss: 1.06, valid acc: 71.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 9
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.97, train acc: 74.5%
# valid loss: 0.97, valid acc: 74.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 10
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.90, train acc: 76.5%
# valid loss: 0.90, valid acc: 76.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 11
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.85, train acc: 77.8%
# valid loss: 0.84, valid acc: 77.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 12
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.81, train acc: 78.5%
# valid loss: 0.80, valid acc: 78.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 13
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.78, train acc: 79.0%
# valid loss: 0.77, valid acc: 78.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 14
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.75, train acc: 79.4%
# valid loss: 0.75, valid acc: 79.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 15
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.73, train acc: 79.7%
# valid loss: 0.73, valid acc: 79.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 16
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.71, train acc: 80.0%
# valid loss: 0.71, valid acc: 80.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 17
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.70, train acc: 80.2%
# valid loss: 0.70, valid acc: 80.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 18
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.69, train acc: 80.6%
# valid loss: 0.68, valid acc: 80.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 19
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.68, train acc: 80.8%
# valid loss: 0.67, valid acc: 80.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 20
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.67, train acc: 80.9%
# valid loss: 0.66, valid acc: 81.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 21
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.66, train acc: 81.2%
# valid loss: 0.65, valid acc: 81.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 22
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.65, train acc: 81.3%
# valid loss: 0.65, valid acc: 81.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 23
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.64, train acc: 81.5%
# valid loss: 0.64, valid acc: 81.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 24
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 81.7%
# valid loss: 0.63, valid acc: 81.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 25
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.63, train acc: 81.9%
# valid loss: 0.62, valid acc: 81.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 26
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 82.0%
# valid loss: 0.62, valid acc: 82.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 27
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.62, train acc: 82.2%
# valid loss: 0.61, valid acc: 82.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 28
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.61, train acc: 82.4%
# valid loss: 0.61, valid acc: 82.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 29
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 82.5%
# valid loss: 0.60, valid acc: 82.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 30
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.60, train acc: 82.7%
# valid loss: 0.59, valid acc: 82.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 31
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 82.8%
# valid loss: 0.59, valid acc: 82.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 32
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.59, train acc: 83.0%
# valid loss: 0.58, valid acc: 83.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 33
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.58, train acc: 83.1%
# valid loss: 0.58, valid acc: 83.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 34
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.58, train acc: 83.2%
# valid loss: 0.58, valid acc: 83.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 35
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.57, train acc: 83.3%
# valid loss: 0.57, valid acc: 83.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 36
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.57, train acc: 83.5%
# valid loss: 0.57, valid acc: 83.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 37
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.56, train acc: 83.6%
# valid loss: 0.56, valid acc: 83.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 38
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.56, train acc: 83.7%
# valid loss: 0.56, valid acc: 83.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 39
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.55, train acc: 83.8%
# valid loss: 0.55, valid acc: 83.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 40
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.55, train acc: 83.9%
# valid loss: 0.55, valid acc: 83.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 41
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.54, train acc: 84.1%
# valid loss: 0.55, valid acc: 83.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 42
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.54, train acc: 84.2%
# valid loss: 0.54, valid acc: 84.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 43
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.54, train acc: 84.3%
# valid loss: 0.54, valid acc: 84.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 44
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.53, train acc: 84.4%
# valid loss: 0.54, valid acc: 84.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 45
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.53, train acc: 84.5%
# valid loss: 0.53, valid acc: 84.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 46
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.53, train acc: 84.6%
# valid loss: 0.53, valid acc: 84.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 47
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.52, train acc: 84.7%
# valid loss: 0.53, valid acc: 84.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 48
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.52, train acc: 84.7%
# valid loss: 0.52, valid acc: 84.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 49
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.52, train acc: 84.8%
# valid loss: 0.52, valid acc: 84.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 50
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.51, train acc: 84.9%
# valid loss: 0.52, valid acc: 84.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 51
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.51, train acc: 85.0%
# valid loss: 0.51, valid acc: 84.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 52
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.51, train acc: 85.1%
# valid loss: 0.51, valid acc: 85.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 53
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.50, train acc: 85.2%
# valid loss: 0.51, valid acc: 85.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 54
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.50, train acc: 85.3%
# valid loss: 0.51, valid acc: 85.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 55
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.50, train acc: 85.4%
# valid loss: 0.50, valid acc: 85.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 56
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.49, train acc: 85.5%
# valid loss: 0.50, valid acc: 85.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 57
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.49, train acc: 85.5%
# valid loss: 0.50, valid acc: 85.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 58
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.49, train acc: 85.6%
# valid loss: 0.50, valid acc: 85.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 59
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.49, train acc: 85.7%
# valid loss: 0.49, valid acc: 85.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 60
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.48, train acc: 85.8%
# valid loss: 0.49, valid acc: 85.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 61
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.48, train acc: 85.8%
# valid loss: 0.49, valid acc: 85.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 62
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.48, train acc: 85.9%
# valid loss: 0.49, valid acc: 85.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 63
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.47, train acc: 86.0%
# valid loss: 0.48, valid acc: 85.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 64
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.47, train acc: 86.0%
# valid loss: 0.48, valid acc: 85.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 65
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.47, train acc: 86.1%
# valid loss: 0.48, valid acc: 85.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 66
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.47, train acc: 86.2%
# valid loss: 0.48, valid acc: 85.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 67
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.46, train acc: 86.3%
# valid loss: 0.47, valid acc: 86.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 68
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.46, train acc: 86.3%
# valid loss: 0.47, valid acc: 86.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 69
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.46, train acc: 86.4%
# valid loss: 0.47, valid acc: 86.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 70
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.46, train acc: 86.4%
# valid loss: 0.47, valid acc: 86.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 71
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.45, train acc: 86.5%
# valid loss: 0.47, valid acc: 86.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 72
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.45, train acc: 86.6%
# valid loss: 0.46, valid acc: 86.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 73
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.45, train acc: 86.7%
# valid loss: 0.46, valid acc: 86.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 74
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.45, train acc: 86.7%
# valid loss: 0.46, valid acc: 86.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 75
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.45, train acc: 86.8%
# valid loss: 0.46, valid acc: 86.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 76
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.44, train acc: 86.8%
# valid loss: 0.46, valid acc: 86.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 77
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.44, train acc: 86.9%
# valid loss: 0.46, valid acc: 86.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 78
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.44, train acc: 87.0%
# valid loss: 0.45, valid acc: 86.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 79
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.44, train acc: 87.1%
# valid loss: 0.45, valid acc: 86.9%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 80
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.44, train acc: 87.1%
# valid loss: 0.45, valid acc: 87.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 81
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.43, train acc: 87.1%
# valid loss: 0.45, valid acc: 87.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 82
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.43, train acc: 87.2%
# valid loss: 0.45, valid acc: 87.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 83
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.43, train acc: 87.3%
# valid loss: 0.44, valid acc: 87.0%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 84
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.43, train acc: 87.3%
# valid loss: 0.44, valid acc: 87.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 85
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.43, train acc: 87.4%
# valid loss: 0.44, valid acc: 87.2%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 86
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.42, train acc: 87.4%
# valid loss: 0.44, valid acc: 87.1%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 87
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.42, train acc: 87.5%
# valid loss: 0.44, valid acc: 87.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 88
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.42, train acc: 87.6%
# valid loss: 0.44, valid acc: 87.3%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 89
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.42, train acc: 87.6%
# valid loss: 0.43, valid acc: 87.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 90
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.42, train acc: 87.6%
# valid loss: 0.43, valid acc: 87.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 91
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.41, train acc: 87.7%
# valid loss: 0.43, valid acc: 87.4%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 92
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.41, train acc: 87.8%
# valid loss: 0.43, valid acc: 87.5%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 93
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.41, train acc: 87.8%
# valid loss: 0.43, valid acc: 87.6%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 94
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.41, train acc: 87.9%
# valid loss: 0.43, valid acc: 87.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 95
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.41, train acc: 87.9%
# valid loss: 0.43, valid acc: 87.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 96
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.41, train acc: 87.9%
# valid loss: 0.42, valid acc: 87.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 97
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.40, train acc: 88.0%
# valid loss: 0.42, valid acc: 87.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 98
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.40, train acc: 88.1%
# valid loss: 0.42, valid acc: 87.7%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 99
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.40, train acc: 88.1%
# valid loss: 0.42, valid acc: 87.8%
# ---------------------------------------------------------
# ---------------------------------------------------------
# Epoch: 100
# ---------------------------------------------------------
# ---------------------------------------------------------
# train loss: 0.40, train acc: 88.2%
# valid loss: 0.42, valid acc: 87.9%
# ---------------------------------------------------------
# ---------------------------------------------------------

# %%
reg_loss, reg_acc = reg_model.evaluate(test_X, test_y)
reg_loss, reg_acc
# Out:
# (0.21289702, 0.9410023)

# %%
def calc_lr(current_iteration, iterations_count):        
        adaptive_rate = 30

        return 0.005 * adaptive_rate ** (1-(current_iteration / iterations_count))

# %%
lr_list = list()
for e in range(100):
    lr_list.append(calc_lr(e,100))

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(lr_list)
plt.title('Adaptive Learning rate')
plt.ylabel('Learning rate')
plt.xlabel('Epoch')
plt.show()

# %%
models = {
    'Base': base_model,
    'Drop + Reg': reg_drop_model,
    'Drop + Reg + A_lr': reg_drop_adaptive_model,
    'Adaptive lr': reg_model,
}

# %%
def plot_curves(title, data, y_title, x_title='Epoch', legend=[], x_labels_offset = 0):
    fig = plt.figure(figsize=(8, 4))
        
    for row in data:
        x = range(x_labels_offset, len(row))
        plt.plot(x, row[x_labels_offset:])
    
    plt.title(title)
    plt.ylabel(y_title)
    plt.xlabel(x_title)
    plt.grid(True)
    plt.legend(legend, loc='upper left')
    plt.show()

# %%
for name in models:
    offset = 40
    m = models[name]
    
    plot_curves(f'{name} - Accuracy', [m.history['acc_train'], m.history['acc_valid']], 'Accuracy', 'Epoch', ['Train', 'Valid'])
    plot_curves(f'{name} - Accuracy', [m.history['acc_train'], m.history['acc_valid']], 'Accuracy', 'Epoch', ['Train', 'Valid'], x_labels_offset=offset)
    plot_curves(f'{name} - Loss', [m.history['loss_train'], m.history['loss_valid']], 'Loss', 'Epoch', ['Train', 'Valid'])
    plot_curves(f'{name} - Loss', [m.history['loss_train'], m.history['loss_valid']], 'Loss', 'Epoch', ['Train', 'Valid'], x_labels_offset=offset)

# %%
loses = list()
acc = list()
labels = list()
for name in models:
    m = models[name]
    labels.append(name)
    loses.append(m.history['loss_valid'])
    acc.append(m.history['acc_valid'])

# %%
plot_curves(f'Accuracy', acc, 'Accuracy', 'Epoch', labels, x_labels_offset=10)

# %%
plot_curves(f'Loss', loses, 'Loss', 'Epoch', labels, x_labels_offset=30)

# %%
labels = list()
test_acc = list()
for name in models:
    m = models[name]
    labels.append(name)
    _, t_acc = m.evaluate(test_X, test_y)
    test_acc.append(t_acc)

labels, test_acc
# Out:
# (['Base', 'Drop + Reg', 'Drop + Reg + A_lr', 'Adaptive lr'],
#  [0.93979603, 0.9312973, 0.93031037, 0.9410023])

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(labels,test_acc, color=['Blue', 'Orange', 'Green', 'Red'])
plt.ylim(0.929, 0.945)
plt.show()
